# %% [markdown]
# ## Fraud Detection Optimization ML Training

# %% [raw]
# Goal:
# *****
# Perform EDA on creditcard.csv + train a baseline Logistic Regression fraud detector.
#
# - EDA: Class distribution, amount patterns, time of fraud.
# - Model: Logistic Regression baseline with class_weight='balanced'.
# - Metrics: F1-score, ROC AUC, PR Curve.
# - Saved model as baseline_model.pkl.

# %% [markdown]
# ### Setup & Load Dataset

# %%
# Import libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, precision_recall_curve

from imblearn.over_sampling import SMOTE

# %%
# Load data

df = pd.read_csv('creditcard.csv')

# %%
# Drop duplicates

df.drop_duplicates(inplace=True)

# %%
# Basic info

print(df.shape)
print(df['Class'].value_counts())
# Out:
# (283726, 31)
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
# Separate features/target

X = df.drop(['Class', 'Time'], axis=1)
y = df['Class']

# Scale 'Amount'

scaler = StandardScaler()
X['Amount'] = scaler.fit_transform(X['Amount'].values.reshape(-1, 1))

# %% [markdown]
# ### EDA - Class Imbalance & Distributions

# %%
# Class distribution

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Class')
plt.title("Fraud (1) vs Non-Fraud (0)")
plt.show()

# %%
# Amount Distribution by Class

plt.figure(figsize=(10,4))
sns.histplot(data=df[df['Class']==0]['Amount'], bins=100, color='green', label='Non-Fraud', stat='density', alpha=0.6)
sns.histplot(data=df[df['Class']==1]['Amount'], bins=100, color='red', label='Fraud', stat='density', alpha=0.6)
plt.legend()
plt.title("Transaction Amount Distribution")
plt.show()

# %% [markdown]
# ### Correlation & Time Patterns

# %%
# Correlation heatmap

corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.show()

# %%
# Fraud over Time

df['Hour'] = df['Time'] // 3600
plt.figure(figsize=(10,4))
sns.histplot(data=df[df['Class']==1], x='Hour', bins=24, color='red', label='Fraud', stat='count')
plt.legend()
plt.title("Fraud Frequency by Hour")
plt.show()

# %% [markdown]
# ### Train/Test Split + Apply SMOTE

# %%
# split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

print(f"Train size: {X_train.shape}, Test size: {X_test.shape}")
# Out:
# Train size: (198608, 29), Test size: (85118, 29)

# %%
# Apply SMOTE only on training set

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print(f"Before SMOTE: {y_train.value_counts()}")
print(f"After SMOTE: {pd.Series(y_train_resampled).value_counts()}")
# Out:
# Before SMOTE: Class
# 0    198277
# 1       331
# Name: count, dtype: int64
# After SMOTE: Class
# 0    198277
# 1    198277
# Name: count, dtype: int64

# %% [markdown]
# ### Train Logistic Regression (Balanced)

# %%
model = LogisticRegression(max_iter=1000, solver='liblinear')
model.fit(X_train_resampled, y_train_resampled)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %% [markdown]
# ### Evaluate on Original Test Set

# %%
y_pred = model.predict(X_test)
y_probs = model.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9998    0.9723    0.9858     84976
#            1     0.0504    0.8803    0.0953       142
#
#     accuracy                         0.9721     85118
#    macro avg     0.5251    0.9263    0.5406     85118
# weighted avg     0.9982    0.9721    0.9844     85118

# %%
# Confusion matrix

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### ROC and PR Curves

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_probs)
plt.plot(fpr, tpr, label=f'ROC AUC = {roc_auc_score(y_test, y_probs):.4f}')
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.title("ROC Curve")
plt.show()

# %%
# PR Curve
precision, recall, _ = precision_recall_curve(y_test, y_probs)
plt.plot(recall, precision)
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.show()

# %% [raw]
# Evaluation Analysis:
# ********************
#
# Interpretation of Evaluation Scores:
#
# Class 0 (Non-Fraud):
# Precision = 0.9998 -> Almost all predicted non-frauds were correct
# Recall = 0.9723 -> 97.23% of actual non-frauds were detected
# F1 = 0.9858 -> Strong performance overall
#
# Class 1 (Fraud):
# Precision = 0.0504 -> Only ~5% of predicted frauds were actually fraud -> High false positives
# Recall = 0.8803 -> 88% of actual frauds were caught -> Great
# F1 = 0.0953 -> Low, due to imbalance between precision and recall
#
#
# - The model is not overfitting, but rather underperforming on precision due to:
#   - Severe class imbalance
#   - Logistic Regression’s limited capacity
#
#
# ROC AUC:
# ROC AUC (Receiver Operating Characteristic - Area Under Curve) measures how well your model separates the fraud and non-fraud classes at various thresholds.
#
# AUC = 1.0 -> Perfect classifier
# AUC = 0.5 -> Random guess
# Model: 0.9659 -> Excellent at distinguishing fraud from non-fraud
#
#
# - While the model is very good at ranking fraud versus non-fraud, it still predicts too many false positives (low precision).
# - Even with a high ROC AUC, if your classification threshold is fixed (default 0.5), you may get:
#   - High recall, but
#   - Poor precision (false alarms)
#
#
# Let's implement the Random Forest model, which captures non-linear patterns, handles imbalanced data more effectively, and supports feature importance.

# %% [markdown]
# ### Train Random Forest Model

# %%
# Features & label
X = df.drop("Class", axis=1)
y = df["Class"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Handle class imbalance with SMOTE
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# %%
# Train baseline Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, max_depth=8, random_state=42)
rf_model.fit(X_train_smote, y_train_smote)
# Out:
# RandomForestClassifier(max_depth=8, random_state=42)

# %% [markdown]
# ### Threshold Tuning Using F1 Score

# %%
import numpy as np

# Predict probabilities
y_probs = rf_model.predict_proba(X_test_scaled)[:, 1]

# Get precision-recall-thresholds
precisions, recalls, thresholds = precision_recall_curve(y_test, y_probs)

# Compute F1 for each threshold
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-6)
best_thresh = thresholds[np.argmax(f1_scores)]
print(f"Best Threshold: {best_thresh:.4f} | Best F1 Score: {max(f1_scores):.4f}")

# Predict with best threshold
y_pred_thresh = (y_probs >= best_thresh).astype(int)
# Out:
# Best Threshold: 0.8113 | Best F1 Score: 0.7955

# %% [markdown]
# ### Evaluation Metrics

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred_thresh)
print("Confusion Matrix:\n", cm)

# Classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred_thresh, digits=4))
# Out:
# Confusion Matrix:
# [[56640    11]
#  [   25    70]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9996    0.9998    0.9997     56651
#            1     0.8642    0.7368    0.7955        95
#
#     accuracy                         0.9994     56746
#    macro avg     0.9319    0.8683    0.8976     56746
# weighted avg     0.9993    0.9994    0.9993     56746

# %%
# ROC AUC

auc_score = roc_auc_score(y_test, y_probs)
print(f"ROC AUC Score: {auc_score:.4f}")
# Out:
# ROC AUC Score: 0.9773

# %% [markdown]
# ### Plot F1 vs Threshold

# %%
plt.figure(figsize=(10, 6))
plt.plot(thresholds, f1_scores[:-1])
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.title("F1 Score vs. Threshold for RandomForest")
plt.grid(True)
plt.show()

# %% [raw]
# Evaluation Analysis:
# ********************
#
# Confusion Matrix Analysis:
# |                      | Predicted 0    | Predicted 1 |
# | -------------------- | -------------- | ----------- |
# | Actual 0 (Non-Fraud) | **56640** (TN) | **11** (FP) |
# | Actual 1 (Fraud)     | **25** (FN)    | **70** (TP) |
#
# Observations:
# - Very low FP (11) -> Good! Very few non-fraud transactions were flagged wrongly.
# - Moderate FN (25) -> Not bad, but ideally we'd like to catch more frauds.
# - High True Positive (70/95 actual frauds detected) → Good recall.
#
#
# Classification Report Explained:
# | Class         | Precision | Recall | F1-score | Support |
# | ------------- | --------- | ------ | -------- | ------- |
# | 0 (Non-Fraud) | 0.9996    | 0.9998 | 0.9997   | 56651   |
# | 1 (Fraud)     | 0.8642    | 0.7368 | 0.7955   | 95      |
#
# - Precision (Fraud) = 0.8642 → Among flagged frauds, ~86% were truly fraud.
# - Recall (Fraud) = 0.7368 → You detected ~73.7% of all frauds.
# - F1 Score (Fraud) = 0.7955 → Good harmonic balance between precision and recall.
#
# Macro vs Weighted Averages:
# | Metric    | Macro Avg | Weighted Avg |
# | --------- | --------- | ------------ |
# | Precision | 0.9319    | 0.9993       |
# | Recall    | 0.8683    | 0.9994       |
# | F1-Score  | 0.8976    | 0.9993       |
#
# - Macro avg = unweighted avg (good for seeing performance across classes).
# - Weighted avg = accounts for class imbalance → favors class 0 heavily due to more samples.
#
#
# ROC-AUC:
# - ROC-AUC is still ~0.96+ (as before), which suggests the ranking capability of the model is very good.
#
#
# No major signs of overfitting:
# - Very high precision & recall for majority class is expected.
# - Decent recall for minority class (73%) and no sign of the model memorizing.
# - We used SMOTE during training, which also helps generalization.

# %% [markdown]
# ### Ensemble Stacking (RF + XGBoost + Logistic Regression)

# %% [raw]
# Ensemble Stacking often improves performance by combining multiple models (like RandomForest, XGBoost, and Logistic Regression) and learning how to best combine their predictions using a meta-model (often LogisticRegression).
#
#
# Goal:
# - Train 3 base models:
#    - RandomForestClassifier
#    - XGBClassifier
#    - LogisticRegression
# - Use LogisticRegression as a meta-learner
# - Evaluate stacked ensemble on the validation set

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import StackingClassifier

# SMOTE for balancing 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

sm = SMOTE(random_state=42)
X_train_sm, y_train_sm = sm.fit_resample(X_train_scaled, y_train)

# %%
# Define base learners
base_learners = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='logloss', n_estimators=100, random_state=42)),
    ('lr', LogisticRegression(max_iter=500))
]

# %%
# Meta-learner: Logistic Regression
stack_model = StackingClassifier(
    estimators=base_learners,
    final_estimator=LogisticRegression(max_iter=500),
    cv=5,
    n_jobs=-1
)

# %%
# Fit ensemble model
stack_model.fit(X_train_sm, y_train_sm)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('rf', RandomForestClassifier(random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='logloss',
#                                               feature_types=None,
#                                               feature_weights=None, gamma=Non...
# ...

# %%
# Evaluate
y_pred = stack_model.predict(X_test_scaled)
print("📊 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\n📄 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 📊 Confusion Matrix:
# [[93459    15]
#  [   34   122]]
#
# 📄 Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93474
#            1       0.89      0.78      0.83       156
#
#     accuracy                           1.00     93630
#    macro avg       0.95      0.89      0.92     93630
# weighted avg       1.00      1.00      1.00     93630

# %% [raw]
# Let's interpret the Ensemble Stacking evaluation results in detail:
# *******************************************************************
#
# |              | Predicted 0 (Not Fraud) | Predicted 1 (Fraud) |
# | ------------ | ----------------------- | ------------------- |
# | **Actual 0** | 93,459 (TN)             | 15 (FP)             |
# | **Actual 1** | 34 (FN)                 | 122 (TP)            |
#
# - True Negatives (TN): 93,459 -> Non-fraud predicted correctly.
# - True Positives (TP): 122 -> Fraud predicted correctly.
# - False Positives (FP): 15 -> Non-fraud predicted as fraud.
# - False Negatives (FN): 34 -> Fraud missed by the model.
#
#
# Classification Report:
# **********************
#
# | Metric        | Class 0 (Non-Fraud) | Class 1 (Fraud) | Explanation                                      |
# | ------------- | ------------------- | --------------- | ------------------------------------------------ |
# | **Precision** | 1.00                | 0.89            | Of all predicted frauds, 89% were actual frauds  |
# | **Recall**    | 1.00                | 0.78            | Of all real frauds, 78% were correctly predicted |
# | **F1-score**  | 1.00                | 0.83            | Harmonic mean of precision & recall              |
#
# - Accuracy: ≈ 1.00 -> But this is misleading in imbalanced datasets.
#    - Macro Avg (treats both classes equally):
#    - Precision: 0.95
#    - Recall: 0.89
# - F1-score: 0.92
# - Weighted Avg (accounts for imbalance): Very close to 1.00, due to class 0 dominating.
#
#
# Key Observations:
# *****************
#
# - High precision on fraud (0.89):
# Few false positives - good for user experience (less chance of blocking valid transactions).
#
# - Recall on fraud is 0.78:
# ~22% of fraud cases are still missed.
# You may want to tune threshold to improve recall if catching fraud is mission-critical.
#
# - Balanced F1-score for class 1: 0.83:
# Indicates a good trade-off between precision and recall.
#
#
# How Ensemble Helped:
# ********************
#
# - Compared to individual models:
#    - Logistic Regression alone had low recall on class 1.
#    - Random Forest had decent recall, but not as balanced precision.
#    - XGBoost often overshoots precision but underperforms on minority class recall.
#
# - Ensemble stacking:
#    - Combining their strengths using a meta-learner
#    - Boosts generalization and smoothens overfitting

# %% [raw]
# Comparative evaluation summary between the Random Forest model and the Ensemble Stacking model (Random Forest + XGBoost + Logistic Regression).
#
# 1. Confusion Matrix Comparison:
# *******************************
#
# | Metric | Random Forest | Ensemble Stacking |
# | ------ | ------------- | ----------------- |
# | **TN** | 56,640        | 93,459            |
# | **FP** | 11            | 15                |
# | **FN** | 25            | 34                |
# | **TP** | 70            | 122               |
#
# - Both models maintain very low false positive rates, which is critical in not flagging valid users.
# - Ensemble caught more fraud cases (TP = 122 vs 70), despite slightly higher false positives and false negatives.
#
#
# 2. Classification Report Summary:
# *********************************
#
# | Metric        | Random Forest (Class 1 - Fraud) | Ensemble Stacking (Class 1 - Fraud) |
# | ------------- | ------------------------------- | ----------------------------------- |
# | **Precision** | 0.8642                          | 0.89                                |
# | **Recall**    | 0.7368                          | 0.78                                |
# | **F1-score**  | 0.7955                          | 0.83                                |
# | **Accuracy**  | 0.9994                          | ≈1.00                               |
#
# - Precision Improved: From 0.86 -> 0.89
#    - Fewer false fraud alerts (good UX)
#
# - Recall Improved: From 0.73 -> 0.78
#    - More frauds caught
#
# - F1-score Improved: From 0.79 -> 0.83
#    - Better balance of precision & recall
#
#
# 3. Macro Average (Better for Imbalanced Data):
# **********************************************
#
# | Metric              | Random Forest | Ensemble |
# | ------------------- | ------------- | -------- |
# | **Macro Precision** | 0.9319        | 0.95     |
# | **Macro Recall**    | 0.8683        | 0.89     |
# | **Macro F1-score**  | 0.8976        | 0.92     |
#
# - Ensemble stacking outperforms Random Forest across all macro-averaged metrics, which is more informative in imbalanced settings like fraud detection.
#
#
# 4. Interpretation:
# ******************
#
# | Aspect           | Random Forest                 | Ensemble Stacking                       |
# | ---------------- | ----------------------------- | --------------------------------------- |
# | Simplicity       | Easier to deploy and maintain | More complex, needs more orchestration  |
# | Performance      | Good                          | Superior recall and f1-score            |
# | Overfitting Risk | Lower                         | Slightly higher, can be controlled      |
# | Deployment       | Faster                        | Needs coordination of base + meta model |
#
#
# Summary:
# ********
#
# - Ensemble model offers better fraud recall and F1-score, which is vital in production.
# - Slight increase in complexity is justified by improved fraud detection.
# - Make sure to monitor the ensemble model for overfitting and stability over time.

# %% [markdown]
# ### Save Model + Scaler

# %%
import os

# Create the models directory if it doesn't exist
os.makedirs("../models", exist_ok=True)

# Save model and scaler
joblib.dump(model, "../models/logreg_smote_model.pkl")
joblib.dump(scaler, "../models/scaler.pkl")
print("Saved model and scaler to '../models/'")
# Out:
# Saved model and scaler to '../models/'

# %%
# Save to a Custom Local Path

joblib.dump(model, "logreg_smote_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
